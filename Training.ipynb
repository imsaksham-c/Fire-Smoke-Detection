# %%
import os
from torchvision import datasets
import torchvision
import torch
from torchvision.transforms import transforms
import torchvision.models as models
import numpy as np
from PIL import ImageFile
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
ImageFile.LOAD_TRUNCATED_IMAGES = True
plt.ion()

# %%
batch_size = 64
num_workers = 0

transform = transforms.Compose([
    transforms.Resize(size=(256,256)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
train_set = './dataset/Train/'
valid_set = './dataset/Test/'


train_data = datasets.ImageFolder(train_set, transform=transform)
valid_data = datasets.ImageFolder(valid_set, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)

loaders = {
    'train': train_loader,
    'valid': valid_loader
}

# %%
class_names = ['Fire', 'Neutral', 'Smoke']
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(loaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
model = models.resnet50(pretrained=True)

use_cuda = torch.cuda.is_available()

if use_cuda:
    model = model.cuda()
    
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
for param in model.parameters():
    param.requires_grad = False

model.fc = torch.nn.Sequential(torch.nn.Linear(2048,128),
                                      torch.nn.ReLU(),
                                       torch.nn.Linear(128,3),
                                       torch.nn.Softmax()
                                      )

for param in model.fc.parameters():
    param.requires_grad = True
    
if use_cuda:
    model_transfer = model.cuda()
    
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=3, bias=True)
#     (3): Softmax(dim=None)
#   )
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_transfer.fc.parameters(), lr=0.0005)

# %%
n_epochs = 100

train_accuracy_list = []
train_loss_list = []
valid_accuracy_list = []
valid_loss_list = []

def train(n_epochs, loader, model, optimizer, criterion, use_cuda, save_path):
    
    valid_loss_min = np.Inf
       
    for epoch in range(1, (n_epochs+1)):
        
        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc = 0.0
        
        model.train()
        
        for batch_idx, (data, target) in enumerate(loaders['train']):
            
            if use_cuda:
                data, target = data.cuda(), target.cuda()

            optimizer.zero_grad()
            output = model(data)
            _, preds = torch.max(output, 1)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_acc = train_acc + torch.sum(preds == target.data)
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):

            if use_cuda:
                data, target = data.cuda(), target.cuda()
            output = model(data)
            _, preds = torch.max(output, 1)
            loss = criterion(output, target)
            
            valid_acc = valid_acc + torch.sum(preds == target.data)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            
        train_loss = train_loss/len(loaders['train'].dataset)
        valid_loss = valid_loss/len(loaders['valid'].dataset)
        train_acc = train_acc/len(loaders['train'].dataset)
        valid_acc = valid_acc/len(loaders['valid'].dataset)
        
        train_accuracy_list.append(train_acc)
        train_loss_list.append(train_loss)
        valid_accuracy_list.append(valid_acc)
        valid_loss_list.append(valid_loss)
        
        print('Epoch: {} \tTraining Acc: {:6f} \tTraining Loss: {:6f} \tValidation Acc: {:6f} \tValidation Loss: {:.6f}'.format(
            epoch,
            train_acc,
            train_loss,
            valid_acc,
            valid_loss
            ))

        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss  
            
    return model

# %%
model = train(n_epochs, loaders, model, optimizer, criterion, use_cuda, './trained-models/model_transfer.pt')
# Out:
# /home/ayush/anaconda3/envs/python36/lib/python3.6/site-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch: 1 	Training Acc: 0.796296 	Training Loss: 0.000294 	Validation Acc: 0.866667 	Validation Loss: 0.002338
# Validation loss decreased (inf --> 0.002338).  Saving model ...
# Epoch: 2 	Training Acc: 0.868519 	Training Loss: 0.000257 	Validation Acc: 0.883333 	Validation Loss: 0.002328
# Validation loss decreased (0.002338 --> 0.002328).  Saving model ...
# Epoch: 3 	Training Acc: 0.884074 	Training Loss: 0.000250 	Validation Acc: 0.876667 	Validation Loss: 0.002248
# Validation loss decreased (0.002328 --> 0.002248).  Saving model ...
# Epoch: 4 	Training Acc: 0.891481 	Training Loss: 0.000247 	Validation Acc: 0.893333 	Validation Loss: 0.002287
# Epoch: 5 	Training Acc: 0.894074 	Training Loss: 0.000244 	Validation Acc: 0.883333 	Validation Loss: 0.002243
# Validation loss decreased (0.002248 --> 0.002243).  Saving model ...
# Epoch: 6 	Training Acc: 0.910741 	Training Loss: 0.000240 	Validation Acc: 0.893333 	Validation Loss: 0.002194
# Validation loss decreased (0.002243 --> 0.002194).  Saving model ...
# Epoch: 7 	Training Acc: 0.902963 	Training Loss: 0.000242 	Validation Acc: 0.870000 	Validation Loss: 0.002266
# Epoch: 8 	Training Acc: 0.895926 	Training Loss: 0.000242 	Validation Acc: 0.863333 	Validation Loss: 0.002264
# Epoch: 9 	Training Acc: 0.907407 	Training Loss: 0.000240 	Validation Acc: 0.870000 	Validation Loss: 0.002295
# Epoch: 10 	Training Acc: 0.901852 	Training Loss: 0.000241 	Validation Acc: 0.933333 	Validation Loss: 0.002127
# Validation loss decreased (0.002194 --> 0.002127).  Saving model ...
# Epoch: 11 	Training Acc: 0.894815 	Training Loss: 0.000243 	Validation Acc: 0.900000 	Validation Loss: 0.002179
# Epoch: 12 	Training Acc: 0.917407 	Training Loss: 0.000237 	Validation Acc: 0.893333 	Validation Loss: 0.002200
# Epoch: 13 	Training Acc: 0.902963 	Training Loss: 0.000240 	Validation Acc: 0.883333 	Validation Loss: 0.002235
# Epoch: 14 	Training Acc: 0.908148 	Training Loss: 0.000239 	Validation Acc: 0.880000 	Validation Loss: 0.002253
# Epoch: 15 	Training Acc: 0.908889 	Training Loss: 0.000239 	Validation Acc: 0.903333 	Validation Loss: 0.002180
# Epoch: 16 	Training Acc: 0.887407 	Training Loss: 0.000246 	Validation Acc: 0.873333 	Validation Loss: 0.002219
# Epoch: 17 	Training Acc: 0.913704 	Training Loss: 0.000236 	Validation Acc: 0.913333 	Validation Loss: 0.002167
# Epoch: 18 	Training Acc: 0.900000 	Training Loss: 0.000241 	Validation Acc: 0.883333 	Validation Loss: 0.002188
# Epoch: 19 	Training Acc: 0.912222 	Training Loss: 0.000237 	Validation Acc: 0.910000 	Validation Loss: 0.002137
# Epoch: 20 	Training Acc: 0.910000 	Training Loss: 0.000238 	Validation Acc: 0.890000 	Validation Loss: 0.002199
# Epoch: 21 	Training Acc: 0.915185 	Training Loss: 0.000237 	Validation Acc: 0.903333 	Validation Loss: 0.002166
# Epoch: 22 	Training Acc: 0.906296 	Training Loss: 0.000238 	Validation Acc: 0.913333 	Validation Loss: 0.002142
# Epoch: 23 	Training Acc: 0.902593 	Training Loss: 0.000241 	Validation Acc: 0.906667 	Validation Loss: 0.002154
# Epoch: 24 	Training Acc: 0.916667 	Training Loss: 0.000234 	Validation Acc: 0.890000 	Validation Loss: 0.002193
# Epoch: 25 	Training Acc: 0.912222 	Training Loss: 0.000238 	Validation Acc: 0.870000 	Validation Loss: 0.002247
# Epoch: 26 	Training Acc: 0.905556 	Training Loss: 0.000240 	Validation Acc: 0.883333 	Validation Loss: 0.002212
# Epoch: 27 	Training Acc: 0.916667 	Training Loss: 0.000236 	Validation Acc: 0.883333 	Validation Loss: 0.002223
# Epoch: 28 	Training Acc: 0.914074 	Training Loss: 0.000235 	Validation Acc: 0.873333 	Validation Loss: 0.002265
# Epoch: 29 	Training Acc: 0.908518 	Training Loss: 0.000238 	Validation Acc: 0.883333 	Validation Loss: 0.002225
# Epoch: 30 	Training Acc: 0.902963 	Training Loss: 0.000239 	Validation Acc: 0.880000 	Validation Loss: 0.002234
# Epoch: 31 	Training Acc: 0.895556 	Training Loss: 0.000242 	Validation Acc: 0.876667 	Validation Loss: 0.002234
# Epoch: 32 	Training Acc: 0.913333 	Training Loss: 0.000236 	Validation Acc: 0.883333 	Validation Loss: 0.002198
# Epoch: 33 	Training Acc: 0.915926 	Training Loss: 0.000235 	Validation Acc: 0.873333 	Validation Loss: 0.002255
# Epoch: 34 	Training Acc: 0.916296 	Training Loss: 0.000234 	Validation Acc: 0.873333 	Validation Loss: 0.002260
# Epoch: 35 	Training Acc: 0.904444 	Training Loss: 0.000239 	Validation Acc: 0.873333 	Validation Loss: 0.002251
# Epoch: 36 	Training Acc: 0.899630 	Training Loss: 0.000243 	Validation Acc: 0.886667 	Validation Loss: 0.002202
# Epoch: 37 	Training Acc: 0.912222 	Training Loss: 0.000237 	Validation Acc: 0.880000 	Validation Loss: 0.002231
# Epoch: 38 	Training Acc: 0.912593 	Training Loss: 0.000238 	Validation Acc: 0.893333 	Validation Loss: 0.002193
# Epoch: 39 	Training Acc: 0.916296 	Training Loss: 0.000235 	Validation Acc: 0.870000 	Validation Loss: 0.002274
# Epoch: 40 	Training Acc: 0.908889 	Training Loss: 0.000238 	Validation Acc: 0.893333 	Validation Loss: 0.002185
# Epoch: 41 	Training Acc: 0.910370 	Training Loss: 0.000237 	Validation Acc: 0.906667 	Validation Loss: 0.002144
# Epoch: 42 	Training Acc: 0.914444 	Training Loss: 0.000236 	Validation Acc: 0.890000 	Validation Loss: 0.002216
# Epoch: 43 	Training Acc: 0.917037 	Training Loss: 0.000235 	Validation Acc: 0.880000 	Validation Loss: 0.002218
# Epoch: 44 	Training Acc: 0.913704 	Training Loss: 0.000236 	Validation Acc: 0.873333 	Validation Loss: 0.002260
# Epoch: 45 	Training Acc: 0.920370 	Training Loss: 0.000233 	Validation Acc: 0.880000 	Validation Loss: 0.002241
# Epoch: 46 	Training Acc: 0.924074 	Training Loss: 0.000231 	Validation Acc: 0.843333 	Validation Loss: 0.002307
# Epoch: 47 	Training Acc: 0.911852 	Training Loss: 0.000236 	Validation Acc: 0.896667 	Validation Loss: 0.002174
# Epoch: 48 	Training Acc: 0.917407 	Training Loss: 0.000234 	Validation Acc: 0.873333 	Validation Loss: 0.002229
# Epoch: 49 	Training Acc: 0.912593 	Training Loss: 0.000235 	Validation Acc: 0.880000 	Validation Loss: 0.002217
# Epoch: 50 	Training Acc: 0.923704 	Training Loss: 0.000233 	Validation Acc: 0.886667 	Validation Loss: 0.002150
# Epoch: 51 	Training Acc: 0.909259 	Training Loss: 0.000237 	Validation Acc: 0.890000 	Validation Loss: 0.002200
# Epoch: 52 	Training Acc: 0.909259 	Training Loss: 0.000236 	Validation Acc: 0.910000 	Validation Loss: 0.002159
# Epoch: 53 	Training Acc: 0.914815 	Training Loss: 0.000235 	Validation Acc: 0.900000 	Validation Loss: 0.002172
# Epoch: 54 	Training Acc: 0.910370 	Training Loss: 0.000236 	Validation Acc: 0.893333 	Validation Loss: 0.002190
# Epoch: 55 	Training Acc: 0.913704 	Training Loss: 0.000234 	Validation Acc: 0.896667 	Validation Loss: 0.002161
# Epoch: 56 	Training Acc: 0.914815 	Training Loss: 0.000235 	Validation Acc: 0.883333 	Validation Loss: 0.002208
# Epoch: 57 	Training Acc: 0.921481 	Training Loss: 0.000233 	Validation Acc: 0.893333 	Validation Loss: 0.002189
# Epoch: 58 	Training Acc: 0.918889 	Training Loss: 0.000234 	Validation Acc: 0.886667 	Validation Loss: 0.002227
# Epoch: 59 	Training Acc: 0.916667 	Training Loss: 0.000236 	Validation Acc: 0.906667 	Validation Loss: 0.002135
# Epoch: 60 	Training Acc: 0.914815 	Training Loss: 0.000234 	Validation Acc: 0.866667 	Validation Loss: 0.002258
# Epoch: 61 	Training Acc: 0.910370 	Training Loss: 0.000236 	Validation Acc: 0.903333 	Validation Loss: 0.002130
# Epoch: 62 	Training Acc: 0.920370 	Training Loss: 0.000234 	Validation Acc: 0.896667 	Validation Loss: 0.002170
# Epoch: 63 	Training Acc: 0.922963 	Training Loss: 0.000233 	Validation Acc: 0.880000 	Validation Loss: 0.002237
# Epoch: 64 	Training Acc: 0.911111 	Training Loss: 0.000235 	Validation Acc: 0.883333 	Validation Loss: 0.002226
# Epoch: 65 	Training Acc: 0.924815 	Training Loss: 0.000231 	Validation Acc: 0.896667 	Validation Loss: 0.002174
# Epoch: 66 	Training Acc: 0.923704 	Training Loss: 0.000232 	Validation Acc: 0.896667 	Validation Loss: 0.002180
# Epoch: 67 	Training Acc: 0.917037 	Training Loss: 0.000233 	Validation Acc: 0.883333 	Validation Loss: 0.002186
# Epoch: 68 	Training Acc: 0.916296 	Training Loss: 0.000235 	Validation Acc: 0.903333 	Validation Loss: 0.002153
# Epoch: 69 	Training Acc: 0.923333 	Training Loss: 0.000232 	Validation Acc: 0.870000 	Validation Loss: 0.002274
# Epoch: 70 	Training Acc: 0.904444 	Training Loss: 0.000239 	Validation Acc: 0.890000 	Validation Loss: 0.002193
# Epoch: 71 	Training Acc: 0.916667 	Training Loss: 0.000234 	Validation Acc: 0.880000 	Validation Loss: 0.002237
# Epoch: 72 	Training Acc: 0.926667 	Training Loss: 0.000232 	Validation Acc: 0.866667 	Validation Loss: 0.002268
# Epoch: 73 	Training Acc: 0.901111 	Training Loss: 0.000239 	Validation Acc: 0.883333 	Validation Loss: 0.002226
# Epoch: 74 	Training Acc: 0.919630 	Training Loss: 0.000233 	Validation Acc: 0.903333 	Validation Loss: 0.002165
# Epoch: 75 	Training Acc: 0.912963 	Training Loss: 0.000235 	Validation Acc: 0.863333 	Validation Loss: 0.002281
# Epoch: 76 	Training Acc: 0.914444 	Training Loss: 0.000235 	Validation Acc: 0.900000 	Validation Loss: 0.002186
# Epoch: 77 	Training Acc: 0.918519 	Training Loss: 0.000233 	Validation Acc: 0.883333 	Validation Loss: 0.002222
# Epoch: 78 	Training Acc: 0.923333 	Training Loss: 0.000233 	Validation Acc: 0.883333 	Validation Loss: 0.002212
# Epoch: 79 	Training Acc: 0.917037 	Training Loss: 0.000234 	Validation Acc: 0.896667 	Validation Loss: 0.002185
# Epoch: 80 	Training Acc: 0.911111 	Training Loss: 0.000235 	Validation Acc: 0.893333 	Validation Loss: 0.002202
# Epoch: 81 	Training Acc: 0.918519 	Training Loss: 0.000233 	Validation Acc: 0.883333 	Validation Loss: 0.002209
# Epoch: 82 	Training Acc: 0.924074 	Training Loss: 0.000232 	Validation Acc: 0.893333 	Validation Loss: 0.002186
# Epoch: 83 	Training Acc: 0.925556 	Training Loss: 0.000231 	Validation Acc: 0.896667 	Validation Loss: 0.002171
# Epoch: 84 	Training Acc: 0.922593 	Training Loss: 0.000233 	Validation Acc: 0.880000 	Validation Loss: 0.002208
# Epoch: 85 	Training Acc: 0.918148 	Training Loss: 0.000234 	Validation Acc: 0.850000 	Validation Loss: 0.002301
# Epoch: 86 	Training Acc: 0.915556 	Training Loss: 0.000235 	Validation Acc: 0.870000 	Validation Loss: 0.002246
# Epoch: 87 	Training Acc: 0.917037 	Training Loss: 0.000234 	Validation Acc: 0.856667 	Validation Loss: 0.002272
# Epoch: 88 	Training Acc: 0.921852 	Training Loss: 0.000232 	Validation Acc: 0.906667 	Validation Loss: 0.002159
# Epoch: 89 	Training Acc: 0.925185 	Training Loss: 0.000231 	Validation Acc: 0.880000 	Validation Loss: 0.002212
# Epoch: 90 	Training Acc: 0.919630 	Training Loss: 0.000235 	Validation Acc: 0.900000 	Validation Loss: 0.002196
# Epoch: 91 	Training Acc: 0.920370 	Training Loss: 0.000235 	Validation Acc: 0.906667 	Validation Loss: 0.002148
# Epoch: 92 	Training Acc: 0.924444 	Training Loss: 0.000232 	Validation Acc: 0.890000 	Validation Loss: 0.002198
# Epoch: 93 	Training Acc: 0.918519 	Training Loss: 0.000235 	Validation Acc: 0.906667 	Validation Loss: 0.002163
# Epoch: 94 	Training Acc: 0.916296 	Training Loss: 0.000234 	Validation Acc: 0.896667 	Validation Loss: 0.002189
# Epoch: 95 	Training Acc: 0.916296 	Training Loss: 0.000234 	Validation Acc: 0.890000 	Validation Loss: 0.002200
# Epoch: 96 	Training Acc: 0.915556 	Training Loss: 0.000236 	Validation Acc: 0.860000 	Validation Loss: 0.002244
# Epoch: 97 	Training Acc: 0.916667 	Training Loss: 0.000233 	Validation Acc: 0.873333 	Validation Loss: 0.002250
# Epoch: 98 	Training Acc: 0.934444 	Training Loss: 0.000229 	Validation Acc: 0.910000 	Validation Loss: 0.002156
# Epoch: 99 	Training Acc: 0.923333 	Training Loss: 0.000232 	Validation Acc: 0.866667 	Validation Loss: 0.002257
# Epoch: 100 	Training Acc: 0.923704 	Training Loss: 0.000232 	Validation Acc: 0.893333 	Validation Loss: 0.002213

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(train_loss_list, label="train_loss")
plt.title("Train-Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")

# %%
plt.style.use("ggplot")
plt.figure()

plt.plot(train_accuracy_list, label="train_acc")
plt.plot(valid_accuracy_list, label="valid_acc")

plt.title("Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %%
torch.save(model, './trained-models/model_final.pth')

# %%
from PIL import Image

class_names = class_names = ['Fire', 'Neutral', 'Smoke']

def predict(image):
    prediction_transform = transforms.Compose([transforms.Resize(size=(224, 224)),
                                     transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    image = prediction_transform(image)[:3,:,:].unsqueeze(0)
    image = image.cuda()

    pred = model(image)
    idx = torch.argmax(pred)
    prob = pred[0][idx].item()*100
    
    return class_names[idx], prob

# %%
def app(path):
    img = Image.open(path)
    plt.imshow(img)
    plt.show()

    prediction, prob = predict(img)
    print(prediction, prob)
    

for img_file in os.listdir('./test-imgs/'):
    img_path = os.path.join('./test-imgs/', img_file)
    app(img_path)
# Out:
# Fire 98.37146401405334
# Fire 100.0
# Fire 100.0
# Fire 98.8549530506134
# Smoke 100.0
# Smoke 99.99969005584717
# Fire 99.99995231628418
# Neutral 100.0
# Neutral 57.175761461257935
# Neutral 99.99998807907104
# Smoke 99.99997615814209
# Neutral 100.0
# Smoke 99.99840259552002
# Smoke 94.36390995979309
